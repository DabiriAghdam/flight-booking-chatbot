# %% [markdown]
# <h3 align=center> In His Name, the Most High </h3>

# %%
#importing libraries
import re
import matplotlib.pyplot as plt
plt.style.use('seaborn') # beautiful plots :O

# %% [markdown]
# ## ATIS Dataset EDA

# %% [markdown]
# The ATIS dataset is a standard benchmark dataset widely used for intent classification and slot filling.
# here we obtained the dataset from https://github.com/yvchen/JointSLU.

# %%
#importing train data

train_words = list() # a list of list of words for every sentence in train dataset
train_tags = list() # a list of list of IOB tags for every sentence in train dataset
train_intents = list() # a list of intent for every sentence in train dataset
train_data = list() # a list of dicts contaiting above data in a more structured form
train_vocabs = set() # a set containing whole train dataset words

with open('atis-2.train+dev.w-intent.iob') as f:
    for line in f.readlines():
        line = line.strip().split()
        
        index = 0
        words = list()
        for i, word in enumerate(line[:-1]):
            if (word == 'EOS'):
                index = i
                break
            if (word != 'BOS'): 
                # what to do if not word.isalpha()??
                # word = re.sub(r'[^\w\s]', '', word) # removing punctuations
                word = re.sub("[?|'|!|.]","", word) # removing punctuations
                word = word.lower() # lowerizing word
                words.append(word) 
                train_vocabs.add(word)
        
        tags = list()
        for tag in line[index + 2:-1]:
            tags.append(tag)
                    
        # handling entries with multiple intents
        intent = ""
        if ('#' in line[-1]): 
            for item in line[-1].split('#'):
                intent = item
                break
        else: intent = line[-1]

        if (intent != 'atis_cheapest'): #droping 'atis_cheapest' because it has only 1 sample!
          train_words.append(words)
          train_tags.append(tags)
          train_intents.append(intent)
          train_data.append({
              'words': words,
              'iob_tags': tags,
              #             'length': len(words),
              'intent': intent})

print('train dataset vocab size:', len(train_vocabs))
print('# of train dataset rows:', len(train_data))
print('# of train dataset unique intents:', len(set(train_intents)))
print('# of train dataset unique IOB tags:', len(set([tag for item in train_tags for tag in item])))
# Out:
# train dataset vocab size: 895
# # of train dataset rows: 4977
# # of train dataset unique intents: 16
# # of train dataset unique IOB tags: 121

# %%
ind = 0
train_data[ind]
# Out:
# {'intent': 'atis_flight',
#  'iob_tags': ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-fromloc.city_name',
#   'O',
#   'B-toloc.city_name',
#   'B-round_trip',
#   'I-round_trip'],
#  'words': ['i',
#   'want',
#   'to',
#   'fly',
#   'from',
#   'baltimore',
#   'to',
#   'dallas',
#   'round',
#   'trip']}

# %%
print('tokenized words:', train_data[ind]['words'])
print('IOB tags:', train_data[ind]['iob_tags'])
print('intent:', train_data[ind]['intent'])
# Out:
# tokenized words: ['i', 'want', 'to', 'fly', 'from', 'baltimore', 'to', 'dallas', 'round', 'trip']
# IOB tags: ['O', 'O', 'O', 'O', 'O', 'B-fromloc.city_name', 'O', 'B-toloc.city_name', 'B-round_trip', 'I-round_trip']
# intent: atis_flight

# %%
train_intents_freq = dict()
for intent in set(train_intents):
    train_intents_freq[intent] = train_intents.count(intent)
    
for key in train_intents_freq:
    value = train_intents_freq[key]
    print('%s: %d (%.2f%%),' % (key, value, value / len(train_intents) * 100))
# Out:
# atis_meal: 6 (0.12%),
# atis_airline: 159 (3.19%),
# atis_city: 19 (0.38%),
# atis_airfare: 424 (8.52%),
# atis_distance: 20 (0.40%),
# atis_restriction: 6 (0.12%),
# atis_flight: 3687 (74.08%),
# atis_abbreviation: 147 (2.95%),
# atis_aircraft: 82 (1.65%),
# atis_ground_fare: 18 (0.36%),
# atis_flight_time: 54 (1.08%),
# atis_quantity: 51 (1.02%),
# atis_flight_no: 12 (0.24%),
# atis_airport: 20 (0.40%),
# atis_ground_service: 256 (5.14%),
# atis_capacity: 16 (0.32%),

# %%
plt.figure(figsize=(24, 8))
plt.bar(list(train_intents_freq.keys()),train_intents_freq.values())
plt.show()

# %%
train_tags_freq = dict()
count = 0
for item in train_tags:
    for tag in item:
        if (tag in train_tags_freq): train_tags_freq[tag] += 1 #item.count(tag)
        else: train_tags_freq[tag] = 1 #item.count(tag)
        count += 1

for key in train_tags_freq:
    value = train_tags_freq[key]
    print('%s: %d (%.2f%%),' % (key, value, value / count * 100))
# Out:
# O: 35662 (63.46%),
# B-fromloc.city_name: 4326 (7.70%),
# B-toloc.city_name: 4343 (7.73%),
# B-round_trip: 348 (0.62%),
# I-round_trip: 339 (0.60%),
# B-cost_relative: 343 (0.61%),
# B-fare_amount: 53 (0.09%),
# I-fare_amount: 51 (0.09%),
# B-arrive_date.month_name: 47 (0.08%),
# B-arrive_date.day_number: 47 (0.08%),
# I-fromloc.city_name: 691 (1.23%),
# B-stoploc.city_name: 239 (0.43%),
# B-arrive_time.time_relative: 187 (0.33%),
# B-arrive_time.time: 208 (0.37%),
# I-arrive_time.time: 161 (0.29%),
# B-toloc.state_code: 86 (0.15%),
# I-toloc.city_name: 1099 (1.96%),
# I-stoploc.city_name: 47 (0.08%),
# B-meal_description: 57 (0.10%),
# B-depart_date.month_name: 379 (0.67%),
# B-depart_date.day_number: 395 (0.70%),
# B-airline_name: 701 (1.25%),
# I-airline_name: 421 (0.75%),
# B-depart_time.period_of_day: 593 (1.06%),
# B-depart_date.day_name: 889 (1.58%),
# B-toloc.state_name: 77 (0.14%),
# B-depart_time.time_relative: 323 (0.57%),
# B-depart_time.time: 369 (0.66%),
# B-toloc.airport_name: 39 (0.07%),
# I-toloc.airport_name: 49 (0.09%),
# B-depart_date.date_relative: 82 (0.15%),
# B-or: 66 (0.12%),
# B-airline_code: 136 (0.24%),
# B-class_type: 217 (0.39%),
# I-class_type: 183 (0.33%),
# I-cost_relative: 55 (0.10%),
# I-depart_time.time: 299 (0.53%),
# B-fromloc.airport_name: 89 (0.16%),
# I-fromloc.airport_name: 119 (0.21%),
# B-city_name: 227 (0.40%),
# B-flight_mod: 329 (0.59%),
# B-meal: 46 (0.08%),
# B-economy: 36 (0.06%),
# B-fare_basis_code: 76 (0.14%),
# I-depart_date.day_number: 120 (0.21%),
# B-depart_date.today_relative: 84 (0.15%),
# B-flight_stop: 168 (0.30%),
# B-airport_code: 29 (0.05%),
# B-fromloc.state_name: 39 (0.07%),
# I-fromloc.state_name: 9 (0.02%),
# I-city_name: 49 (0.09%),
# B-connect: 40 (0.07%),
# B-arrive_date.day_name: 88 (0.16%),
# B-fromloc.state_code: 46 (0.08%),
# B-arrive_date.today_relative: 2 (0.00%),
# B-depart_date.year: 25 (0.04%),
# B-depart_time.start_time: 25 (0.04%),
# I-depart_time.start_time: 13 (0.02%),
# B-depart_time.end_time: 25 (0.04%),
# I-depart_time.end_time: 18 (0.03%),
# B-arrive_time.start_time: 21 (0.04%),
# B-arrive_time.end_time: 20 (0.04%),
# I-arrive_time.end_time: 19 (0.03%),
# I-flight_mod: 11 (0.02%),
# B-flight_days: 39 (0.07%),
# B-mod: 30 (0.05%),
# B-flight_number: 84 (0.15%),
# I-toloc.state_name: 13 (0.02%),
# B-meal_code: 6 (0.01%),
# I-meal_code: 4 (0.01%),
# B-airport_name: 38 (0.07%),
# I-airport_name: 54 (0.10%),
# I-flight_stop: 17 (0.03%),
# B-transport_type: 48 (0.09%),
# I-transport_type: 23 (0.04%),
# B-state_code: 8 (0.01%),
# B-aircraft_code: 31 (0.06%),
# B-toloc.country_name: 3 (0.01%),
# I-arrive_date.day_number: 6 (0.01%),
# B-toloc.airport_code: 20 (0.04%),
# B-return_date.date_relative: 10 (0.02%),
# I-return_date.date_relative: 2 (0.00%),
# B-flight_time: 71 (0.13%),
# I-economy: 10 (0.02%),
# B-fromloc.airport_code: 15 (0.03%),
# B-arrive_time.period_of_day: 64 (0.11%),
# B-depart_time.period_mod: 44 (0.08%),
# I-flight_time: 32 (0.06%),
# B-return_date.day_name: 1 (0.00%),
# B-arrive_date.date_relative: 11 (0.02%),
# B-restriction_code: 23 (0.04%),
# I-restriction_code: 14 (0.02%),
# B-arrive_time.period_mod: 4 (0.01%),
# I-arrive_time.period_of_day: 3 (0.01%),
# B-period_of_day: 5 (0.01%),
# B-stoploc.state_code: 5 (0.01%),
# I-depart_date.today_relative: 12 (0.02%),
# I-fare_basis_code: 2 (0.00%),
# I-arrive_time.start_time: 8 (0.01%),
# B-time: 2 (0.00%),
# B-today_relative: 2 (0.00%),
# I-today_relative: 3 (0.01%),
# B-state_name: 2 (0.00%),
# B-days_code: 3 (0.01%),
# I-depart_time.period_of_day: 6 (0.01%),
# I-arrive_time.time_relative: 2 (0.00%),
# B-time_relative: 1 (0.00%),
# I-time: 1 (0.00%),
# B-return_date.month_name: 4 (0.01%),
# B-return_date.day_number: 4 (0.01%),
# I-depart_time.time_relative: 2 (0.00%),
# B-stoploc.airport_name: 1 (0.00%),
# B-day_name: 5 (0.01%),
# B-month_name: 2 (0.00%),
# B-day_number: 2 (0.00%),
# B-return_time.period_mod: 2 (0.00%),
# B-return_time.period_of_day: 3 (0.01%),
# B-return_date.today_relative: 1 (0.00%),
# I-return_date.today_relative: 2 (0.00%),
# I-meal_description: 1 (0.00%),
# I-return_date.day_number: 1 (0.00%),

# %%
#importing test data

test_words = list()  # a list of list of words for every sentence in test dataset
test_tags = list() # a list of list of IOB tags for every sentence in test dataset
test_intents = list() # a list of intent for every sentence in test dataset
test_vocabs = set() # a list of dicts contaiting above data in a more structured form
test_data = list() # a set containing whole test dataset words

with open('atis.test.w-intent.iob') as f:
    for line in f.readlines():
        line = line.strip().split()
        
        index = 0
        words = list()
        for i, word in enumerate(line[:-1]):
            if (word == 'EOS'):
                index = i
                break
            if (word != 'BOS'): 
                word = re.sub(r'[^\w\s]', '', word.lower()) # removing punctuations & lowerizing word
                words.append(word) 
                train_vocabs.add(word)
        test_words.append(words)
        
        tags = list()
        for tag in line[index + 2:-1]:
            tags.append(tag)
        test_tags.append(tags)
                    
        #handling entries with multiple intents
        intent = ""
        if ('#' in line[-1]): 
            for item in line[-1].split('#'):
                intent = item
                break
        else: intent = line[-1]
        test_intents.append(intent)
        
        test_data.append({
            'words': words,
            'iob_tags': tags,
            #             'length': len(words),
            'intent': intent})

print('train dataset vocab size:', len(test_vocabs))
print('# of test dataset rows:', len(test_data))
print('# of test dataset unique intents:', len(set(test_intents)))
print('# of test dataset unique IOB tags:', len(set([tag for item in test_tags for tag in item])))
# Out:
# train dataset vocab size: 0
# # of test dataset rows: 893
# # of test dataset unique intents: 16
# # of test dataset unique IOB tags: 101

# %%
ind = 0
print('tokenized words:', test_data[ind]['words'])
print('IOB tags:', test_data[ind]['iob_tags'])
print('intent:', test_data[ind]['intent'])
# Out:
# tokenized words: ['i', 'would', 'like', 'to', 'find', 'a', 'flight', 'from', 'charlotte', 'to', 'las', 'vegas', 'that', 'makes', 'a', 'stop', 'in', 'st', 'louis']
# IOB tags: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-fromloc.city_name', 'O', 'B-toloc.city_name', 'I-toloc.city_name', 'O', 'O', 'O', 'O', 'O', 'B-stoploc.city_name', 'I-stoploc.city_name']
# intent: atis_flight

# %%
test_intents_freq = dict()
for intent in set(test_intents):
    test_intents_freq[intent] = test_intents.count(intent)
    
for key in test_intents_freq:
    value = test_intents_freq[key]
    print('%s: %d (%.2f%%) ,' % (key, value, value / len(test_intents) * 100))
# Out:
# atis_meal: 6 (0.67%) ,
# atis_airline: 38 (4.26%) ,
# atis_city: 6 (0.67%) ,
# atis_airfare: 49 (5.49%) ,
# atis_distance: 10 (1.12%) ,
# atis_capacity: 21 (2.35%) ,
# atis_flight: 645 (72.23%) ,
# atis_ground_fare: 7 (0.78%) ,
# atis_quantity: 3 (0.34%) ,
# atis_airport: 18 (2.02%) ,
# atis_abbreviation: 33 (3.70%) ,
# atis_flight_time: 1 (0.11%) ,
# atis_aircraft: 9 (1.01%) ,
# atis_flight_no: 9 (1.01%) ,
# atis_ground_service: 36 (4.03%) ,
# atis_day_name: 2 (0.22%) ,

# %%
plt.figure(figsize=(24, 8))
plt.bar(list(test_intents_freq.keys()),test_intents_freq.values())
plt.show()

# %%
test_tags_freq = dict()
count = 0
for item in test_tags:
    for tag in item:
        if (tag in test_tags_freq): test_tags_freq[tag] += 1 #item.count(tag)
        else: test_tags_freq[tag] = 1 #item.count(tag)
        count += 1

for key in test_tags_freq:
    value = test_tags_freq[key]
    print('%s: %d (%.2f%%),' % (key, value, value / count * 100))
# Out:
# O: 5501 (60.03%),
# B-fromloc.city_name: 704 (7.68%),
# B-toloc.city_name: 716 (7.81%),
# I-toloc.city_name: 265 (2.89%),
# B-stoploc.city_name: 20 (0.22%),
# I-stoploc.city_name: 10 (0.11%),
# B-depart_date.month_name: 56 (0.61%),
# B-depart_date.day_number: 55 (0.60%),
# B-depart_time.time_relative: 65 (0.71%),
# B-depart_time.time: 57 (0.62%),
# I-depart_time.time: 52 (0.57%),
# B-round_trip: 73 (0.80%),
# I-round_trip: 71 (0.77%),
# B-airline_name: 101 (1.10%),
# I-airline_name: 65 (0.71%),
# B-depart_date.day_name: 212 (2.31%),
# B-depart_time.period_of_day: 130 (1.42%),
# I-fromloc.city_name: 177 (1.93%),
# B-meal_description: 10 (0.11%),
# B-depart_date.date_relative: 17 (0.19%),
# B-arrive_time.time_relative: 31 (0.34%),
# B-arrive_time.time: 34 (0.37%),
# I-arrive_time.time: 35 (0.38%),
# B-return_date.day_name: 2 (0.02%),
# B-arrive_date.date_relative: 2 (0.02%),
# B-arrive_date.day_name: 11 (0.12%),
# B-flight_stop: 21 (0.23%),
# B-depart_date.today_relative: 9 (0.10%),
# B-toloc.state_name: 28 (0.31%),
# B-arrive_date.month_name: 6 (0.07%),
# B-arrive_date.day_number: 6 (0.07%),
# B-arrive_time.start_time: 8 (0.09%),
# B-arrive_time.end_time: 8 (0.09%),
# I-arrive_time.end_time: 8 (0.09%),
# B-airport_name: 21 (0.23%),
# I-airport_name: 29 (0.32%),
# B-connect: 6 (0.07%),
# B-fromloc.airport_name: 12 (0.13%),
# I-fromloc.airport_name: 15 (0.16%),
# B-meal: 16 (0.17%),
# B-flight_number: 11 (0.12%),
# I-flight_number: 1 (0.01%),
# B-return_date.date_relative: 3 (0.03%),
# I-return_date.date_relative: 3 (0.03%),
# B-arrive_time.period_of_day: 6 (0.07%),
# B-fromloc.state_name: 17 (0.19%),
# B-city_name: 57 (0.62%),
# I-city_name: 30 (0.33%),
# I-depart_date.day_number: 15 (0.16%),
# I-depart_time.period_of_day: 1 (0.01%),
# B-cost_relative: 37 (0.40%),
# I-cost_relative: 3 (0.03%),
# B-flight_time: 1 (0.01%),
# I-flight_time: 1 (0.01%),
# B-flight_mod: 24 (0.26%),
# B-class_type: 24 (0.26%),
# I-class_type: 17 (0.19%),
# B-airline_code: 34 (0.37%),
# B-toloc.airport_code: 4 (0.04%),
# B-transport_type: 10 (0.11%),
# B-depart_time.start_time: 3 (0.03%),
# B-depart_time.end_time: 3 (0.03%),
# I-depart_time.end_time: 3 (0.03%),
# B-toloc.airport_name: 3 (0.03%),
# I-toloc.airport_name: 3 (0.03%),
# B-aircraft_code: 33 (0.36%),
# B-toloc.country_name: 1 (0.01%),
# B-mod: 2 (0.02%),
# B-state_name: 9 (0.10%),
# B-compartment: 1 (0.01%),
# B-meal_code: 1 (0.01%),
# B-day_name: 2 (0.02%),
# B-toloc.state_code: 18 (0.20%),
# B-fromloc.state_code: 23 (0.25%),
# B-depart_time.period_mod: 5 (0.05%),
# B-fromloc.airport_code: 5 (0.05%),
# B-fare_basis_code: 17 (0.19%),
# B-flight_days: 10 (0.11%),
# B-depart_date.year: 3 (0.03%),
# B-period_of_day: 4 (0.04%),
# I-flight_mod: 6 (0.07%),
# B-state_code: 1 (0.01%),
# B-restriction_code: 4 (0.04%),
# I-restriction_code: 3 (0.03%),
# B-airport_code: 9 (0.10%),
# B-days_code: 1 (0.01%),
# I-arrive_time.time_relative: 4 (0.04%),
# B-or: 3 (0.03%),
# B-stoploc.airport_code: 1 (0.01%),
# I-depart_time.time_relative: 1 (0.01%),
# I-state_name: 1 (0.01%),
# B-economy: 6 (0.07%),
# B-booking_class: 1 (0.01%),
# B-fare_amount: 2 (0.02%),
# I-fare_amount: 2 (0.02%),
# B-flight: 1 (0.01%),
# I-depart_time.start_time: 1 (0.01%),
# I-arrive_time.start_time: 1 (0.01%),
# I-transport_type: 1 (0.01%),
# I-fromloc.state_name: 1 (0.01%),
# I-toloc.state_name: 1 (0.01%),

# %% [markdown]
# ##### comparing train & test dataset tags & intents:

# %%
print(test_vocabs.difference(train_vocabs))
# Out:
# set()

# %%
set(test_intents).difference(set(train_intents))
# Out:
# {'atis_day_name'}

# %% [markdown]
# so from above, we see there is no train data for 'atis_day_name'...

# %%
set(train_intents).difference(set(test_intents))
# Out:
# {'atis_restriction'}

# %% [markdown]
# and also there are no test data for 'atis_cheapest' & 'atis_restriction'...

# %%
set(test_tags_freq.keys()).difference(set(train_tags_freq.keys()))
# Out:
# {'B-booking_class',
#  'B-compartment',
#  'B-flight',
#  'B-stoploc.airport_code',
#  'I-flight_number',
#  'I-state_name'}

# %% [markdown]
# also we see there are no train data with 'B-stoploc.airport_code' or 'B-booking_class' or 'I-flight_number' or 'I-state_name' or 'B-flight' or 'B-compartment' tag...

# %%
set(train_tags_freq.keys()).difference(set(test_tags_freq.keys()))
# Out:
# {'B-arrive_date.today_relative',
#  'B-arrive_time.period_mod',
#  'B-day_number',
#  'B-month_name',
#  'B-return_date.day_number',
#  'B-return_date.month_name',
#  'B-return_date.today_relative',
#  'B-return_time.period_mod',
#  'B-return_time.period_of_day',
#  'B-stoploc.airport_name',
#  'B-stoploc.state_code',
#  'B-time',
#  'B-time_relative',
#  'B-today_relative',
#  'I-arrive_date.day_number',
#  'I-arrive_time.period_of_day',
#  'I-depart_date.today_relative',
#  'I-economy',
#  'I-fare_basis_code',
#  'I-flight_stop',
#  'I-meal_code',
#  'I-meal_description',
#  'I-return_date.day_number',
#  'I-return_date.today_relative',
#  'I-time',
#  'I-today_relative'}

# %% [markdown]
# and finally there are no train data with 'I-return_date.day_number' or 'B-return_time.period_mod' or ... tag.

# %% [markdown]
# to handle imbalanced data first we try to find and remove duplicates:

# %%
#removing duplicate train data #with 'atis_flight' intent

train_words_dup_free = list()
train_tags_dup_free = list()
train_intents_dup_free = list()
train_data_dup_free = list()
for i in range(len(train_words)):
    words = train_words[i]
    tags = train_tags[i]
    intent = train_intents[i]
    # if (intent != 'atis_flight' or (intent == 'atis_flight' and words not in train_words_dup_free)):
    if (words not in train_words_dup_free):
        train_words_dup_free.append(words)
        train_tags_dup_free.append(tags)
        train_intents_dup_free.append(intent)
        train_data_dup_free.append({
            'words': words,
            'iob_tags': tags,
            #             'length': len(words),
            'intent': intent})

print('# of duplicate sentences in train data: %d - %d = %d' % (len(train_words), len(train_words_dup_free), len(train_words) - len(train_words_dup_free)))
# Out:
# # of duplicate sentences in train data: 4977 - 4633 = 344

# %%
train_intents_dup_free_freq = dict()
for intent in train_intents_dup_free:
    train_intents_dup_free_freq[intent] = train_intents_dup_free.count(intent)

for key in train_intents_dup_free_freq:
    value = train_intents_dup_free_freq[key]
    print('%s: %d (%.2f%%),' % (key, value, value / len(train_intents_dup_free) * 100))
# Out:
# atis_flight: 3443 (72.74%),
# atis_airfare: 424 (8.96%),
# atis_airline: 159 (3.36%),
# atis_ground_service: 256 (5.41%),
# atis_quantity: 51 (1.08%),
# atis_city: 19 (0.40%),
# atis_abbreviation: 147 (3.11%),
# atis_aircraft: 82 (1.73%),
# atis_distance: 20 (0.42%),
# atis_ground_fare: 18 (0.38%),
# atis_capacity: 16 (0.34%),
# atis_flight_time: 54 (1.14%),
# atis_meal: 6 (0.13%),
# atis_flight_no: 12 (0.25%),
# atis_restriction: 6 (0.13%),
# atis_airport: 20 (0.42%),

# %%
plt.figure(figsize=(24, 8))
plt.bar(list(train_intents_dup_free_freq.keys()),train_intents_dup_free_freq.values())
plt.show()

# %%
##removing duplicate test data with 'atis_flight' intent

test_words_dup_free = list()
test_tags_dup_free = list()
test_intents_dup_free = list()
test_data_dup_free = list()
for i in range(len(test_words)):
    words = test_words[i]
    tags = test_tags[i]
    intent = test_intents[i]
    # if (intent != 'atis_flight' or (intent == 'atis_flight' and words not in test_words_dup_free)):
    if (words not in test_words_dup_free):
        test_words_dup_free.append(words)
        test_tags_dup_free.append(tags)
        test_intents_dup_free.append(intent)
        test_data.append({
            'words': words,
            'iob_tags': tags,
#             'length': len(words),
            'intent': intent})


print('# of duplicate sentences in test data: %d - %d = %d' % (len(test_words), len(test_words_dup_free),  len(test_words) - len(test_words_dup_free)))
# Out:
# # of duplicate sentences in test data: 893 - 850 = 43

# %%
test_intents_dup_free_freq = dict()
for intent in set(test_intents_dup_free):
    test_intents_dup_free_freq[intent] = test_intents_dup_free.count(intent)

for key in test_intents_dup_free_freq:
    value = test_intents_dup_free_freq[key]
    print('%s: %d (%.2f%%),' % (key, value, value / len(test_intents_dup_free) * 100))
# Out:
# atis_meal: 6 (0.71%),
# atis_airline: 28 (3.29%),
# atis_city: 5 (0.59%),
# atis_airfare: 49 (5.76%),
# atis_distance: 10 (1.18%),
# atis_capacity: 21 (2.47%),
# atis_flight: 626 (73.65%),
# atis_ground_fare: 7 (0.82%),
# atis_quantity: 3 (0.35%),
# atis_airport: 13 (1.53%),
# atis_abbreviation: 26 (3.06%),
# atis_flight_time: 1 (0.12%),
# atis_aircraft: 8 (0.94%),
# atis_flight_no: 9 (1.06%),
# atis_ground_service: 36 (4.24%),
# atis_day_name: 2 (0.24%),

# %%
plt.figure(figsize=(24, 8))
plt.bar(list(test_intents_dup_free_freq.keys()),test_intents_dup_free_freq.values())
plt.show()

# %% [markdown]
# so we can see that unfortunately removing duplicates didn't have any noticable improvment on balancing the dataset.

# %%
from sklearn.utils import class_weight
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np


def identity_tokenizer(text):
    return text
# define Tokenizer with Vocab Size
# tokenizer = Tokenizer(num_words=len(train_vocabs))
# tokenizer.fit_on_texts(train_words)
vectorizer = TfidfVectorizer(tokenizer=identity_tokenizer,lowercase=False)
x_train = vectorizer.fit_transform(train_words)
x_test = vectorizer.fit_transform(test_words)
# x_train = tokenizer.texts_to_matrix(train_words, mode='tfidf')
# x_test = tokenizer.texts_to_matrix(test_words, mode='tfidf')

encoder = LabelBinarizer()
encoder.fit(train_intents)
y_train = encoder.transform(train_intents)
y_test = encoder.transform(test_intents)
print(encoder.classes_)
print(x_train.shape, y_train.shape)
#class_weight.compute_class_weight('balanced',np.unique(train_intents) ,train_intents)
# Out:
# ['atis_abbreviation' 'atis_aircraft' 'atis_airfare' 'atis_airline'
#  'atis_airport' 'atis_capacity' 'atis_city' 'atis_distance' 'atis_flight'
#  'atis_flight_no' 'atis_flight_time' 'atis_ground_fare'
#  'atis_ground_service' 'atis_meal' 'atis_quantity' 'atis_restriction']
# (4977, 895) (4977, 16)

# %%
desired_count = 500
strategy = {0: desired_count, 15: desired_count}# setting atis_restriction and atis_abbreviation classes count just as an example

# %%
from imblearn.over_sampling import SMOTE, ADASYN
smote = ADASYN(sampling_strategy=strategy, n_neighbors=5) #SMOTE(sampling_strategy='minority', k_neighbors=5)
X_sm, y_sm = smote.fit_resample(x_train, y_train)
print(X_sm.shape, y_sm.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# (5811, 895) (5811, 16)

# %%
y_temp = list(encoder.inverse_transform(y_sm))
temp_freq = dict()
for intent in y_temp:
    temp_freq[intent] = y_temp.count(intent)

for key in temp_freq:
    value = temp_freq[key]
    print('%s: %d (%.2f%%),' % (key, value, value / len(y_temp) * 100))
# Out:
# atis_flight: 3687 (63.45%),
# atis_airfare: 424 (7.30%),
# atis_airline: 159 (2.74%),
# atis_ground_service: 256 (4.41%),
# atis_quantity: 51 (0.88%),
# atis_city: 19 (0.33%),
# atis_abbreviation: 488 (8.40%),
# atis_aircraft: 82 (1.41%),
# atis_distance: 20 (0.34%),
# atis_ground_fare: 18 (0.31%),
# atis_capacity: 16 (0.28%),
# atis_flight_time: 54 (0.93%),
# atis_meal: 6 (0.10%),
# atis_flight_no: 12 (0.21%),
# atis_restriction: 499 (8.59%),
# atis_airport: 20 (0.34%),

# %% [markdown]
# #TO-DO: code cleaning

# %%
def create_iob_file(filename, data):
  f = open(filename, 'w')
  for i in range(len(data)):
    sentence = " ".join(data[i]['words'])
    tags = " ".join(data[i]['iob_tags'])
    intent = data[i]['intent']
    f.write("BOS %s EOS\t%s %s\n" % (sentence, tags, intent))
  f.close()

# %% [markdown]
# # Synonym replacement

# %%
# %%capture
# !pip install numpy requests nlpaug transformers

# %%
# %%capture
import nlpaug.augmenter.word as naw
import nlpaug.model.word_stats as nmw
from nlpaug.util.file.download import DownloadUtil
import nltk
import gensim.downloader as api

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
nltk.download('stopwords')
nltk.download('wordnet')

# glove = api.load('glove-twitter-25') 
DownloadUtil.download_glove(model_name='glove.6B', dest_dir='.') # Download GloVe model

# Train TF-IDF model
# tfidf_model = nmw.TfIdf()
# tfidf_model.train(train_words)
# tfidf_model.save('.')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
stop = nltk.corpus.stopwords.words('english')

# %%
aug_p=0.25
aug_max=5
aug_min=1
syn = naw.SynonymAug(aug_src='wordnet', stopwords=stop, aug_p=aug_p, aug_max=aug_max, aug_min=aug_min)
context = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', stopwords=stop, aug_p=aug_p, aug_max=aug_max, aug_min=aug_min, action="substitute")
emb = naw.WordEmbsAug(model_type='glove', model_path='glove.6B.300d.txt', stopwords=stop, aug_p=aug_p, aug_max=aug_max, aug_min=aug_min, action="substitute")
# tfidf = naw.TfIdfAug(model_path='.',stopwords=stop, aug_p=aug_p, aug_max=aug_max, aug_min=aug_min,action="substitute")
# spell = naw.SpellingAug(dict_path ='.', aug_p=aug_p, aug_max=aug_max, aug_min=aug_min)

# %%
context.augment("what are the fares for flights between atlanta and dfw provided by delta airlines",n=5)
# Out:
# ['what are the rules for operate between montreal and dfw managed by delta airlines',
#  'what are the schedules for flights between frankfurt and dfw supplied by shaw airlines',
#  'what are the fares for flights between dublin and dfw provided by atlantic next',
#  'what are the bids for sections between melbourne and dfw available by delta airlines',
#  'what are the fares for coaches between greenville and dfw tracked by delta?']

# %%
f = open('train_data_generated.pkl','rb')
new_dict = pickle.load(f)
f.close()
len(new_dict)
# train_data_generated = new_dict

# %%
train_data_generated = list(
starting_index = 263
i = starting_index
while (i < len(train_data_dup_free)):
# for i in range(starting_index, len(train_data_dup_free)):
  if (train_data_dup_free[i]['intent'] != 'atis_flight'):
    orig_sentence = " ".join(train_data_dup_free[i]['words'])
    orig_tags = train_data_dup_free[i]['iob_tags']
    orig_intent = train_data_dup_free[i]['intent']
    print('\nindex = %d, intent: %s\noriginal sentence: %s\n' % (i, orig_intent, orig_sentence))

    generated = list()
    generated += context.augment(orig_sentence, n = 5)
    generated += emb.augment(orig_sentence, n = 5)
    generated += syn.augment(orig_sentence, n = 5)
    for j in range(len(generated)):
      if (j % 5 == 0): print()
      print('#%d: %s' % (j, generated[j]))
    new_sentence = ''
    while(True):
      inp = input('\nenter value between 0-'+ str(len(generated) - 1) +' or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : ')
      if (inp.isalpha()):
        if (inp.lower() == 'n'): new_sentence = input('enter new sentence: ')
        elif (inp.lower() == 'r'):
          generated = list()
          generated += context.augment(orig_sentence, n = 5)
          generated += emb.augment(orig_sentence, n = 5)
          generated += syn.augment(orig_sentence, n = 5)
          print('\nindex=%d, intent:%s\noriginal sentence: %s\n' % (i, orig_intent, orig_sentence))
          for j in range(len(generated)):
            if (j % 5 == 0): print()
            print('#%d: %s' % (j, generated[j]))
          continue

        elif (inp.lower() == 'b'):
          print('_' * 80)
          print('\nlast index = %d\nbreaking...' % (i))
          i = len(train_data_dup_free)
          # pickle.dump(train_data_generated, f)
          break
        
        elif (inp.lower() == 's'): break

        else: continue

      elif (inp.isnumeric()):
        inp = int(inp)
        if(inp > 14): continue
        new_sentence = generated[inp]

      else: continue

      ans = input('\noriginal sentence: %s\nnew sentence: %s\nis it ok? (y or n) ' %(orig_sentence, new_sentence))
      if (ans.lower() == 'y' or ans.lower() == 'yes'): break
    
    if (new_sentence != ''):
      new_words = new_sentence.strip().split()
      train_data_generated.append({
              'words': new_words,
              'iob_tags': orig_tags,
  #             'length': len(new_words),
              'intent': orig_intent})     
    
    # pickle.dump(train_data_generated, f)
    print('_' * 80)
  i += 1

import pickle

f = open('train_data_generated.pkl','wb')
pickle.dump(train_data_generated, f)
f.close()
# Out:
# index = 130, intent: atis_ground_service
# original sentence: what kind of ground transportation is available in denver
#
#
# #0: what kind of marine transportation is involved in denver
# #1: what works of ground transportation is new in denver
# #2: what kind of regional transportation is maintained in denver
# #3: what kind of ground noise is available in ~
# #4: what kind of air transportation is available in here
#
# #5: what kind of taken transportation is available in l.a.
# #6: what kind of ground transportation is cost in pittsburgh
# #7: what kind of both transportation is available in nuggets
# #8: what kind of ground transportation is version in oregon
# #9: what because of strikes transportation is available in denver
#
# #10: what variety of land transportation is available in denver
# #11: what variety of ground transportation is uncommitted in denver
# #12: what kind of ground expatriation is uncommitted in denver
# #13: what kind of ground expatriation is available in mile high city
# #14: what kind of ground transferral is available in capital of colorado
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 10
#
# original sentence: what kind of ground transportation is available in denver
# new sentence: what variety of land transportation is available in denver
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 135, intent: atis_airfare
# original sentence: what is the cheapest fare i can get from dallas to denver
#
#
# #0: what is the airport fare i can drive from sydney to denver
# #1: what is the cheapest road i can travel from orlando to denver
# #2: what is the cheapest plate i can order from dallas to hell
# #3: what is the usual assignment i can take from dallas to denver
# #4: what is the mini suv i can bring from dallas to denver
#
# #5: what is the quickest cheap i can give from dallas to denver
# #6: what is the cheapest fare i can help from playoffs to utah
# #7: what is the metered fee i can need from dallas to denver
# #8: what is the cheapest taxes i can? from columbus to denver
# #9: what is the fairest eat i can get from francisco to denver
#
# #10: what is the cheapest fare i can generate from dallas to denver
# #11: what is the brassy transportation i can get from dallas to denver
# #12: what is the crummy transportation i can get from dallas to denver
# #13: what is the bum fare i can have from dallas to denver
# #14: what is the tatty menu i can get from dallas to denver
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=135, intent:atis_airfare
# original sentence: what is the cheapest fare i can get from dallas to denver
#
#
# #0: what is the biggest fare i can get from asia to china
# #1: what is the minimum option i can do from dallas to denver
# #2: what is the cheapest job i can pick from london to denver
# #3: what is the cheapest soul i can deliver from paradise to denver
# #4: what is the more money i can get from dallas to china
#
# #5: what is the smallest fare i can feel from los to denver
# #6: what is the lowest weekday i can would from dallas to denver
# #7: what is the option fare i can get from francisco to downtown
# #8: what is the costlier menu i can get from anaheim to denver
# #9: what is the quietest jetblue i can get from dallas to louisville
#
# #10: what is the cheapest transportation i can get from dallas to denver
# #11: what is the cheapest fare i can pay off from dallas to denver
# #12: what is the punk fare i can convey from dallas to denver
# #13: what is the tacky transportation i can get from dallas to denver
# #14: what is the gaudy transportation i can get from dallas to denver
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=135, intent:atis_airfare
# original sentence: what is the cheapest fare i can get from dallas to denver
#
#
# #0: what is the cheapest fare i can get from birth to that
# #1: what is the additional fare i can buy from michigan to denver
# #2: what is the cheapest man i can get from talking to.
# #3: what is the cheapest choice i can get from portland to ~
# #4: what is the best gift i can get from dallas to them
#
# #5: what is the seller snack i can get from dallas to rams
# #6: what is the cheapest fares i can better from miami to denver
# #7: what is the coolest fare i can kind from dallas to downtown
# #8: what is the generic fare i can kind from dallas to cowboys
# #9: what is the dirtiest passengers i can get from tulsa to denver
#
# #10: what is the brassy fare i can catch from dallas to denver
# #11: what is the cheap transportation i can get from dallas to denver
# #12: what is the cheapest transportation i can catch from dallas to denver
# #13: what is the cheapest fare i can cause from dallas to denver
# #14: what is the brassy fare i can receive from dallas to denver
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 11
#
# original sentence: what is the cheapest fare i can get from dallas to denver
# new sentence: what is the cheap transportation i can get from dallas to denver
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 139, intent: atis_city
# original sentence: what cities are served by canadian airlines international
#
#
# #0: what frequencies are served by iranian airlines international
# #1: what cities are served by sky cellular international
# #2: what cities are tapped by kuwait airlines international
# #3: what cities are described by korea airlines international
# #4: what countries are used by canadian airlines international
#
# #5: what cities are served by russian airlines such
# #6: what cities are also by canadian airlines brought
# #7: what cities are 1956 by provincial airlines international
# #8: what these are served by canadian airlines following
# #9: what cities are 1942 by ontario airlines international
#
# #10: what cities are serve by canadian airlines international
# #11: what city are served by canadian airlines outside
# #12: what cities are serve by canadian airlines international
# #13: what city are dish by canadian airlines international
# #14: what cities are served by canadian airway international
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=139, intent:atis_city
# original sentence: what cities are served by canadian airlines international
#
#
# #0: what cities are wanted by canadian business international
# #1: what places are served by canadian airlines §
# #2: what figures are served by canadian airlines without
# #3: what cities are known by canadian airlines %
# #4: what destinations are served by canadian airlines major
#
# #5: what cities are served by swiss singapore international
# #6: what cities are became by canadian airlines based
# #7: what buildings are served by canadian airlines all
# #8: what various are served by canadian airlines including
# #9: what cities are 1958 by canadian 757 international
#
# #10: what cities are served by canadian airlines external
# #11: what cities are serve well by canadian airlines outside
# #12: what cities are answer by canadian airline business international
# #13: what cities are served by canadian airway international
# #14: what cities are serve by canadian airlines outside
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=139, intent:atis_city
# original sentence: what cities are served by canadian airlines international
#
#
# #0: what areas are served by canadian tire international
# #1: what concentrations are served by canadian airlines only
# #2: what cities are traversed by canadian airlines )
# #3: what exactly are traveled by canadian airlines international
# #4: what cities are served by grand bridge international
#
# #5: what cities are who by nova airlines international
# #6: what cities are lieutenant by canadian airlines from
# #7: what universities are 1981 by canadian airlines international
# #8: what mayors are served by canadian airlines humanitarian
# #9: what citizens are served by canadian airlines financial
#
# #10: what metropolis are served by canadian airlines external
# #11: what metropolis are served by canadian airlines international
# #12: what cities are served by canadian airline business international
# #13: what urban center are served by canadian airlines outside
# #14: what urban center are served by canadian airlines international
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=139, intent:atis_city
# original sentence: what cities are served by canadian airlines international
#
#
# #0: what remained are run by canadian airlines international
# #1: what cities are served by canadian bus -
# #2: what cities are served by canadian airways |
# #3: what cities are served by canadian cbc *
# #4: what cities are served by canadian line >
#
# #5: what counties are served by canadian airlines all
# #6: what cities are 1947 by canadian airlines well
# #7: what cities are assistant by pakistani airlines international
# #8: what country are served by canadian airlines standards
# #9: what cities are served by 2005 airlines country
#
# #10: what cities are serve by canadian airlines outside
# #11: what cities are serve up by canadian airlines external
# #12: what urban center are served by canadian airlines international
# #13: what cities are dish up by canadian airline international
# #14: what cities are suffice by canadian airlines outside
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=139, intent:atis_city
# original sentence: what cities are served by canadian airlines international
#
#
# #0: what cities are services by canadian airlines do
# #1: what codes are served by canadian cellular international
# #2: what cities are toured by japanese airlines international
# #3: what riders are served by canadian coaches international
# #4: what cities are bombed by scandinavian airlines international
#
# #5: what cities are served by finnish subsidiary international
# #6: what cities are 1950 by canadian attendants international
# #7: what venues are served by edmonton airlines international
# #8: what different are served by canadian airtran international
# #9: what districts are 1921 by canadian airlines international
#
# #10: what urban center are served by canadian airline international
# #11: what city are served by canadian airlines international
# #12: what metropolis are served by canadian airlines international
# #13: what cities are service by canadian airlines external
# #14: what city are served by canadian airlines international
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 2
#
# original sentence: what cities are served by canadian airlines international
# new sentence: what cities are toured by japanese airlines international
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 144, intent: atis_ground_service
# original sentence: what kinds of ground transportation is available in dallas fort worth
#
#
# #0: what kinds of ground transportation is available in dallas must mean
# #1: what kinds of duct ceiling is available in dallas fort worth
# #2: what kinds of mass transportation is unavailable in dallas fort worth
# #3: what kinds of easy transportation is available in dallas? worth
# #4: what kinds of airport transportation is available in dallas fort zone
#
# #5: what addition of ground transportation is there in dallas fort worth
# #6: what kinds of if transportation is available in dallas fort £
# #7: what those of ground transportation is available in dallas hood worth
# #8: what useful of ground transportation is options in dallas fort worth
# #9: what kinds of the infrastructure is available in dallas fort worth
#
# #10: what kinds of footing transportation is useable in dallas fort worth
# #11: what kinds of ground transportation is available in dallas fortress worth
# #12: what kinds of ground transportation is available in dallas fortress worth
# #13: what kinds of flat coat transportation is available in dallas fort worth
# #14: what kinds of ground shipping is usable in dallas fort worth
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 11
#
# original sentence: what kinds of ground transportation is available in dallas fort worth
# new sentence: what kinds of ground transportation is available in dallas fortress worth
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 149, intent: atis_distance
# original sentence: what is the distance between pittsburgh airport and downtown pittsburgh
#
#
# #0: what is the distance between pittsburgh neighborhoods and downtown when
# #1: what is the distance between denver airport and downtown /
# #2: what is the distance between pittsburgh metropolitan and southern pittsburgh
# #3: what is the distance between pittsburgh mills and downtown [UNK]
# #4: what is the distance between capitol hall and downtown pittsburgh
#
# #5: what is the measured between astros airport and downtown pittsburgh
# #6: what is the distance between pittsburgh airport and houston edmonton
# #7: what is the distance between st. airport and downtown bruins
# #8: what is the distance between pittsburgh station and downtown post-gazette
# #9: what is the distance between mets airport and downtown shutout
#
# #10: what is the distance between pittsburgh airdrome and downtown pittsburgh
# #11: what is the length between pittsburgh airport and downtown pittsburgh
# #12: what is the aloofness between pittsburgh airport and business district pittsburgh
# #13: what is the distance between pittsburgh drome and downtown pittsburgh
# #14: what is the distance between pittsburgh airport and business district pittsburgh
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 10
#
# original sentence: what is the distance between pittsburgh airport and downtown pittsburgh
# new sentence: what is the distance between pittsburgh airdrome and downtown pittsburgh
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 153, intent: atis_airfare
# original sentence: can you tell me the cheapest one way fare from boston to san francisco
#
#
# #0: can you tell me the cheapest one might fare from boston to south york
# #1: can you tell me the cheapest option way down from texas to san francisco
# #2: can you tell me the destination one boat fare from boston to ti francisco
# #3: can you tell me the code one a fare from boston to general francisco
# #4: can you tell me the little one way station from sydney to san francisco
#
# #5: can you say me the buy last way fare from boston to san francisco
# #6: can you able me the cheapest five way fare from hartford to san francisco
# #7: can you tell me the cheapest one what meals from boston to los francisco
# #8: can you tell me the smoothest years i fare from boston to san francisco
# #9: can you tell me the costing one way snacks from angeles to san francisco
#
# #10: can you tell me the cheapest i way menu from boston to san francisco
# #11: can you tell me the cheapest one direction fare from boston to san francisco
# #12: can you tell me the tawdry i way menu from boston to san francisco
# #13: can you tell me the cheap unitary path fare from boston to san francisco
# #14: can you tell me the cheapest unrivalled fashion fare from beantown to san francisco
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=153, intent:atis_airfare
# original sentence: can you tell me the cheapest one way fare from boston to san francisco
#
#
# #0: can you tell me the cheapest one we fare from la to an francisco
# #1: can you tell me the red rail way fare from boston to san francisco
# #2: can you tell me the latest one ship fare from boston to co francisco
# #3: can you play me the cheapest five way fare from boston to san andreas
# #4: can you tell me the numbers one can... from boston to san francisco
#
# #5: can you tell me the cheapest part certainly fare from boston to oakland francisco
# #6: can you tell me the cheapest many way frills from orlando to san francisco
# #7: can you tell me the smallest one way roundtrip from indianapolis to san francisco
# #8: can you tell me the cheapest one be fare from london to houston francisco
# #9: can you tell me the cheapest because this fare from cambridge to san francisco
#
# #10: can you secernate me the cheapest ace way transportation from boston to san francisco
# #11: can you tell me the cheapest one agency transportation from boston to san francisco
# #12: can you tell me the cheapest i mode fare from bean town to san francisco
# #13: can you assure me the trashy one direction fare from boston to san francisco
# #14: can you tell me the garish one room fare from capital of massachusetts to san francisco
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=153, intent:atis_airfare
# original sentence: can you tell me the cheapest one way fare from boston to san francisco
#
#
# #0: can you tell me the cheapest pay way fare from santiago to san gabriel
# #1: can you phone me the cheapest one way transit from boston to san marino
# #2: can you tell me the cheapest one jet fare from kathmandu to san ॥
# #3: can you tell me the following one way bill from boston to san washington
# #4: can you pay me the cheapest covered way fare from detroit to san francisco
#
# #5: can you tell me the airfare yet everything fare from boston to san francisco
# #6: can you tell me the seller one way parking from boston to san oakland
# #7: can you really me the cheapest one way diners from boston to san diego
# #8: can you tell me the 499 one move fare from boston to san torres
# #9: can you tell me the quietest one way fare from manhattan to san solano
#
# #10: can you tell me the tatty one way menu from boston to san francisco
# #11: can you severalise me the cheapest one way menu from boston to san francisco
# #12: can you recount me the tawdry one way of life fare from boston to san francisco
# #13: can you recite me the cheapest ace way fare from boston to san francisco
# #14: can you narrate me the cheapest unrivaled way fare from boston to san francisco
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=153, intent:atis_airfare
# original sentence: can you tell me the cheapest one way fare from boston to san francisco
#
#
# #0: can you tell me the cheapest hal way fare from wilmington to prince francisco
# #1: can you dial me the cheapest one way call from maine to san francisco
# #2: can you make me the cheapest travel way fare from boston to new francisco
# #3: can you report me the cheapest one boat fare from boston to patrick francisco
# #4: can you deal me the cheapest one way fare from portugal to de francisco
#
# #5: can you tell me the lowest one way fare from washington to san josé
# #6: can you tell me the cheapest fact way fare from boston to city mexican
# #7: can you tell me the cheapest one way travelers from boston to valley california
# #8: can you tell me the cheapest way way fare from boston to baltimore miami
# #9: can you tell me the cheapest put way fare from boston to bernardino javier
#
# #10: can you tell me the cheapest 1 way menu from boston to san francisco
# #11: can you tell me the cheapest one way fare from bean town to san francisco
# #12: can you tell me the chintzy one elbow room fare from boston to san francisco
# #13: can you tell me the cheapest one agency menu from boston to san francisco
# #14: can you narrate me the cheapest one way fare from boston to san francisco
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 5
#
# original sentence: can you tell me the cheapest one way fare from boston to san francisco
# new sentence: can you tell me the lowest one way fare from washington to san josé
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 154, intent: atis_airline
# original sentence: what airlines are there
#
#
# #0: what monsters are there
# #1: what windows are there
# #2: what friends are there
# #3: what angels are there
# #4: what else are there
#
# #5: what airplane are there
# #6: what boeing are there
# #7: what trans are there
# #8: what asiana are there
# #9: what ansett are there
#
# #10: what airline are there
# #11: what airline are there
# #12: what airline are there
# #13: what airline are there
# #14: what airway are there
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 10
#
# original sentence: what airlines are there
# new sentence: what airline are there
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 156, intent: atis_airline
# original sentence: is there an airline that advertises having more flights than any other airline
#
#
# #0: is there an american that stops having more flights than any other question
# #1: is there an ambulance that advertises having more passengers than any other if
# #2: is there an agreement that not having more flights than any other |
# #3: is there an astronaut that keeps having more flights than any other oh
# #4: is there an answer that, having more runway than any other airline
#
# #5: is there an airline that adorns having more bound than any other garuda
# #6: is there an airline that embeds having more hubs than any other canceled
# #7: is there an transportation that disdains having more flights than any other usair
# #8: is there an cancellations that recycles having more flights than any other service
# #9: is there an operate that advertises having more cancel than any other passengers
#
# #10: is there an airway that push having more flight of steps than any other airline
# #11: is there an air hose that advertises having more flight than any other airline business
# #12: is there an air hose that advertises having more flight than any other airway
# #13: is there an airline business that advertise having more flights than any other airway
# #14: is there an airline business that advertize having more flights than any other airline business
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=156, intent:atis_airline
# original sentence: is there an airline that advertises having more flights than any other airline
#
#
# #0: is there an amazing that? having more resources than any other airline
# #1: is there an airline that wants having more fares than any other as
# #2: is there an article that said having more flights than any other ×
# #3: is there an difference that already having more pilots than any other airline
# #4: is there an indicator that advertises having more connections than any other in
#
# #5: is there an aircraft that extols having more flights than any other routes
# #6: is there an airline that peddles having more airplane than any other flying
# #7: is there an business that scrutinises having more flying than any other airline
# #8: is there an operating that data.gov having more flights than any other tickets
# #9: is there an airline that 0269 having more flight than any other airlines
#
# #10: is there an airline business that advertise having more flights than any other airline business
# #11: is there an air hose that promote having more flights than any other air hose
# #12: is there an airway that advertize having more flight than any other airline
# #13: is there an air hose that publicize having more flights than any other airline business
# #14: is there an airline business that advertise having more flight than any other airline
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=156, intent:atis_airline
# original sentence: is there an airline that advertises having more flights than any other airline
#
#
# #0: is there an airline that likes having more operators than any other only
# #1: is there an airplanes that... having more flights than any other relative
# #2: is there an airline that sells having more income than any other less
# #3: is there an agent that knows having more flights than any other from
# #4: is there an airline that claims having more weight than any other ×
#
# #5: is there an airline that voraciously having more bound than any other airbus
# #6: is there an delta that extols having more runways than any other airline
# #7: is there an airline that advertisements having more fly than any other freight
# #8: is there an continental that distributes having more flights than any other concorde
# #9: is there an cargo that advertises having more cargo than any other fare
#
# #10: is there an airway that publicise having more flight than any other airline
# #11: is there an airline business that advertises having more flight than any other airway
# #12: is there an airline business that advertise having more flights than any other airway
# #13: is there an airline business that advertize having more escape than any other airline
# #14: is there an airway that advertize having more flying than any other airline
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=156, intent:atis_airline
# original sentence: is there an airline that advertises having more flights than any other airline
#
#
# #0: is there an apple that advertises having more destinations than any other chance
# #1: is there an experiment that works having more options than any other airline
# #2: is there an airline that has having more revenue than any other -
# #3: is there an apartment that now having more flights than any other on
# #4: is there an economy that not having more airports than any other airline
#
# #5: is there an airline that manifesting having more airplanes than any other klm
# #6: is there an business that advertises having more haneda than any other airtran
# #7: is there an jal that advertises having more airspace than any other costs
# #8: is there an airliners that circumlocution having more flights than any other aviation
# #9: is there an airline that proudly having more delays than any other easyjet
#
# #10: is there an air hose that advertize having more flights than any other air hose
# #11: is there an airline business that advertize having more flights than any other airway
# #12: is there an airline that publicize having more flight than any other airline business
# #13: is there an airline business that advertises having more flight than any other airline business
# #14: is there an airline that promote having more escape than any other airway
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : s
# ________________________________________________________________________________
#
# index = 158, intent: atis_airfare
# original sentence: what is the lowest fare from denver to atlanta
#
#
# #0: what is the lowest fare from helena to cheyenne
# #1: what is the metro fare from springfield to atlanta
# #2: what is the picture flying from denver to atlanta
# #3: what is the air fare from denver to ·
# #4: what is the latest fare from denver to vegas
#
# #5: what is the lowest sightseeing from mavericks to atlanta
# #6: what is the lowest fare from malone to knoxville
# #7: what is the level fare from denver to fla.
# #8: what is the record fare from phoenix to atlanta
# #9: what is the lowest pricing from denver to suburban
#
# #10: what is the small transportation from denver to atlanta
# #11: what is the lowest transportation from denver to atlanta
# #12: what is the lowest menu from capital of colorado to atlanta
# #13: what is the lowest fare from capital of colorado to atlanta
# #14: what is the lowest transportation from capital of colorado to atlanta
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : s
# ________________________________________________________________________________
#
# index = 167, intent: atis_ground_service
# original sentence: what are the ground transportation services in philadelphia
#
#
# #0: what are the ground source industries in philadelphia
# #1: what are the ground weather services in exactly
# #2: what are the ground transportation holes in you
# #3: what are the signal car services in philadelphia
# #4: what are the modern aircraft services in philadelphia
#
# #5: what are the ground transportation benefits in trenton
# #6: what are the ground transportation care in downtown
# #7: what are the so transportation sectors in philadelphia
# #8: what are the ground buses transportation in philadelphia
# #9: what are the ground subcommittee services in tampa
#
# #10: what are the priming transportation system services in philadelphia
# #11: what are the ground transportation system services in city of brotherly love
# #12: what are the ground fare services in city of brotherly love
# #13: what are the land transportation services in city of brotherly love
# #14: what are the earth transportation services in city of brotherly love
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=167, intent:atis_ground_service
# original sentence: what are the ground transportation services in philadelphia
#
#
# #0: what are the essential transportation services in '
# #1: what are the scheduled transportation arrangements in philadelphia
# #2: what are the average transportation operators in philadelphia
# #3: what are the latest transportation patterns in philadelphia
# #4: what are the ground railway infrastructure in philadelphia
#
# #5: what are the once transportation services in giants
# #6: what are the needed transportation security in philadelphia
# #7: what are the ground transportation assistance in cardinals
# #8: what are the ground traffic security in philadelphia
# #9: what are the ground transportation technology in trenton
#
# #10: what are the undercoat transport services in philadelphia
# #11: what are the ground transfer services in city of brotherly love
# #12: what are the ground conveyance service of process in philadelphia
# #13: what are the ground expatriation services in city of brotherly love
# #14: what are the ground department of transportation service in philadelphia
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=167, intent:atis_ground_service
# original sentence: what are the ground transportation services in philadelphia
#
#
# #0: what are the ground transportation options in for
# #1: what are the ground transportation vehicles in ]
# #2: what are the many transportation services in philadelphia
# #3: what are the trolley transport services in philadelphia
# #4: what are the designated transportation services in /
#
# #5: what are the leaving transportation provider in philadelphia
# #6: what are the ground lodging services in orlando
# #7: what are the it transportation clients in philadelphia
# #8: what are the ground information public in philadelphia
# #9: what are the ground health services in houston
#
# #10: what are the solid ground transportation services in city of brotherly love
# #11: what are the earth dot services in philadelphia
# #12: what are the land transportation services in city of brotherly love
# #13: what are the ground transport services in city of brotherly love
# #14: what are the ground transportation serve in city of brotherly love
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=167, intent:atis_ground_service
# original sentence: what are the ground transportation services in philadelphia
#
#
# #0: what are the ground crew services in you
# #1: what are the online transportation data in philadelphia
# #2: what are the earliest transportation protocols in philadelphia
# #3: what are the ground punching techniques in philadelphia
# #4: what are the ground gas tracks in philadelphia
#
# #5: what are the ground bus services in boston
# #6: what are the ground services services in milwaukee
# #7: what are the into transportation providers in philadelphia
# #8: what are the ground construction assistance in philadelphia
# #9: what are the ground transportation insurance in giants
#
# #10: what are the reason transfer services in philadelphia
# #11: what are the ground conveyance table service in philadelphia
# #12: what are the footing conveyance services in philadelphia
# #13: what are the solid ground transportation divine service in philadelphia
# #14: what are the ground deportation services in city of brotherly love
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=167, intent:atis_ground_service
# original sentence: what are the ground transportation services in philadelphia
#
#
# #0: what are the ground sports policies in philadelphia
# #1: what are the first television services in philadelphia
# #2: what are the vital transportation assets in philadelphia
# #3: what are the five transportation services in unclear
# #4: what are the ground transportation satellites in?
#
# #5: what are the ground airline telephone in philadelphia
# #6: what are the ground routes services in wisconsin
# #7: what are the falling transportation providers in philadelphia
# #8: what are the force transportation wireless in philadelphia
# #9: what are the aircraft transportation centers in philadelphia
#
# #10: what are the ground transportation service in city of brotherly love
# #11: what are the ground transportation robert william service in city of brotherly love
# #12: what are the soil transportation armed service in philadelphia
# #13: what are the ground transportation overhaul in city of brotherly love
# #14: what are the ground exile services in city of brotherly love
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=167, intent:atis_ground_service
# original sentence: what are the ground transportation services in philadelphia
#
#
# #0: what are the biggest communications services in philadelphia
# #1: what are the ground stations system in philadelphia
# #2: what are the ground car services in other
# #3: what are the ground broadcast services in world
# #4: what are the ground transportation reasons in *
#
# #5: what are the nearby sectors services in philadelphia
# #6: what are the they transportation services in calgary
# #7: what are the ground transportation office in sacramento
# #8: what are the ground rail sectors in philadelphia
# #9: what are the ground railway wireless in philadelphia
#
# #10: what are the land transfer services in philadelphia
# #11: what are the land dot services in philadelphia
# #12: what are the ground dot services in city of brotherly love
# #13: what are the ground shipping services in city of brotherly love
# #14: what are the dry land transportation service in philadelphia
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=167, intent:atis_ground_service
# original sentence: what are the ground transportation services in philadelphia
#
#
# #0: what are the ground lighting utilities in philadelphia
# #1: what are the various overhead services in philadelphia
# #2: what are the ground food services in mean
# #3: what are the mass transportation services in on
# #4: what are the ground nine measures in philadelphia
#
# #5: what are the far vehicles services in philadelphia
# #6: what are the ground cost services in braves
# #7: what are the ground administration customer in philadelphia
# #8: what are the ground hub services in carolina
# #9: what are the some transportation services in indiana
#
# #10: what are the ground transit service in philadelphia
# #11: what are the priming coat transportation services in city of brotherly love
# #12: what are the land expatriation services in philadelphia
# #13: what are the undercoat transportation armed service in philadelphia
# #14: what are the earth fare services in philadelphia
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=167, intent:atis_ground_service
# original sentence: what are the ground transportation services in philadelphia
#
#
# #0: what are the land transportation business in philadelphia
# #1: what are the excellent food services in philadelphia
# #2: what are the common transportation services in world
# #3: what are the ground transportation measures in -
# #4: what are the priority transportation services in relation
#
# #5: what are the ground transportation support in florida
# #6: what are the up transportation products in philadelphia
# #7: what are the ground business services in providence
# #8: what are the ground transportation telecommunications in miami
# #9: what are the other transportation programs in philadelphia
#
# #10: what are the primer coat transportation religious service in philadelphia
# #11: what are the land transportation service in philadelphia
# #12: what are the soil transportation serve in philadelphia
# #13: what are the ground transportation service in city of brotherly love
# #14: what are the ground deportation service in philadelphia
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 5
#
# original sentence: what are the ground transportation services in philadelphia
# new sentence: what are the ground transportation support in florida
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 168, intent: atis_abbreviation
# original sentence: what does fare code qo mean
#
#
# #0: what does it code qo mean
# #1: what does one code qo mean
# #2: what does fare code qo "
# #3: what does fare of qo mean
# #4: what does fare code qo to
#
# #5: what does fare code qo everything
# #6: what does weekdays code qo mean
# #7: what does fare usage qo mean
# #8: what does fare law qo mean
# #9: what does rent code qo mean
#
# #10: what does fare code qo mean
# #11: what does fare write in code qo mean
# #12: what does do code qo mean
# #13: what does fare encrypt qo mean
# #14: what does fare inscribe qo mean
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : s
# ________________________________________________________________________________
#
# index = 169, intent: atis_ground_service
# original sentence: ground transportation washington
#
#
# #0: ground transportation (
# #1: regional transportation washington
# #2: ground plate washington
# #3: ground transportation ॥
# #4: ground 4 washington
#
# #5: ground transportation lobbying
# #6: ground freight washington
# #7: ground food washington
# #8: ground transportation beijing
# #9: ground train washington
#
# #10: ground transfer washington
# #11: ground transport washington
# #12: ground transportation washington d.c.
# #13: ground transportation george washington
# #14: ground transfer washington
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 11
#
# original sentence: ground transportation washington
# new sentence: ground transport washington
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 171, intent: atis_airline
# original sentence: what airlines fly between boston and atlanta
#
#
# #0: what hours fly between boston and atlanta
# #1: what little fly between boston and atlanta
# #2: what price fly between boston and atlanta
# #3: what airlines fly between lincoln and atlanta
# #4: what airlines fly between alexandria and atlanta
#
# #5: what usair fly between boston and atlanta
# #6: what airlines fly between boston and ringel
# #7: what airlines you between boston and atlanta
# #8: what airlines fly between brookline and atlanta
# #9: what airlines leave between boston and atlanta
#
# #10: what airlines fly between boston and capital of georgia
# #11: what airlines rainfly between boston and atlanta
# #12: what airlines fly between boston and battle of atlanta
# #13: what airlines fly between boston and battle of atlanta
# #14: what airlines fly between beantown and atlanta
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=171, intent:atis_airline
# original sentence: what airlines fly between boston and atlanta
#
#
# #0: what birds fly between boston and atlanta
# #1: what times fly between boston and atlanta
# #2: what is fly between boston and atlanta
# #3: what all fly between boston and atlanta
# #4: what about fly between boston and atlanta
#
# #5: what travel fly between boston and atlanta
# #6: what continental fly between boston and atlanta
# #7: what airlines send between boston and atlanta
# #8: what airlines fly between cincinnati and atlanta
# #9: what airlines fly between boston and thrasher
#
# #10: what airlines fly between boston and battle of atlanta
# #11: what airlines rainfly between boston and atlanta
# #12: what airlines fly between boston and atlanta
# #13: what airlines rainfly between boston and atlanta
# #14: what airlines rainfly between boston and atlanta
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=171, intent:atis_airline
# original sentence: what airlines fly between boston and atlanta
#
#
# #0: what airlines fly between raleigh and atlanta
# #1: what if fly between boston and atlanta
# #2: what currently fly between boston and atlanta
# #3: what airlines fly between boston and lax
# #4: what airlines fly between boston and springfield
#
# #5: what airlines fly between boston and writes
# #6: what airplanes fly between boston and atlanta
# #7: what flying fly between boston and atlanta
# #8: what airlines fly between harvard and atlanta
# #9: what commuter fly between boston and atlanta
#
# #10: what airlines fly between boston and capital of georgia
# #11: what airlines fly between boston and atlanta
# #12: what airlines fly between boston and capital of georgia
# #13: what airlines fly front between boston and atlanta
# #14: what airlines fly sheet between boston and atlanta
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=171, intent:atis_airline
# original sentence: what airlines fly between boston and atlanta
#
#
# #0: what airlines fly between boston and springfield
# #1: what airlines pass between boston and atlanta
# #2: what airlines fly between boston and ।
# #3: what airlines exist between boston and atlanta
# #4: what will fly between boston and atlanta
#
# #5: what airlines jet between boston and atlanta
# #6: what airlines fly between denver and atlanta
# #7: what airlines fly between detroit and atlanta
# #8: what airlines fly between boston and barnhart
# #9: what airlines fly between boston and journal
#
# #10: what airlines tent fly between boston and atlanta
# #11: what airlines fly between boston and capital of georgia
# #12: what airlines fly between boston and battle of atlanta
# #13: what airlines tent flap between boston and atlanta
# #14: what airlines fly between boston and battle of atlanta
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 7
#
# original sentence: what airlines fly between boston and atlanta
# new sentence: what airlines fly between detroit and atlanta
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 177, intent: atis_airfare
# original sentence: what are the fares from dallas to san francisco on flight dl 217
#
#
# #0: what are the travels from dallas to san francisco on * dl exactly
# #1: what are the fares from there to san francisco on it sham 217
# #2: what are the channels from dallas to san francisco on flight lounge question
# #3: what are the blocks from dallas to oakland francisco on flight dl -
# #4: what are the fares from dallas to san madrid on 1 dl why
#
# #5: what are the fares from oilers to san vicente on first dl 217
# #6: what are the passenger from dallas to san miguel on flight dl 211
# #7: what are the fares from lakers to tucson francisco on flight kcb 217
# #8: what are the itineraries from cleveland to san francisco on piloted dl 217
# #9: what are the fares from atlanta to pedro francisco on airplanes dl 217
#
# #10: what are the fares from dallas to san francisco on trajectory deciliter 217
# #11: what are the fares from dallas to san francisco on flight dl 217
# #12: what are the fares from dallas to san francisco on flight dl 217
# #13: what are the fares from dallas to san francisco on flight dl 217
# #14: what are the fare from dallas to san francisco on trajectory dl 217
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=177, intent:atis_airfare
# original sentence: what are the fares from dallas to san francisco on flight dl 217
#
#
# #0: what are the fares from winnipeg to son francisco on flight # 217
# #1: what are the fares from dallas to novo juan on flight dl do
# #2: what are the paths from dallas to san francisco on, to 217
# #3: what are the fares from oakland to san francisco on flight 96 ~
# #4: what are the fares from nassau to mira monica on flight dl 217
#
# #5: what are the pay from dallas to san oakland on first dl 217
# #6: what are the fares from columbus to costa francisco on travelers dl 217
# #7: what are the fares from dallas to oregon giants on flight lw 217
# #8: what are the charging from eagles to san franciso on flight dl 217
# #9: what are the meals from d.c. to san francisco on flight dl 309
#
# #10: what are the fares from dallas to san francisco on flight of stairs dl 217
# #11: what are the fares from dallas to san francisco on flight deciliter 217
# #12: what are the fares from dallas to san francisco on flight decilitre 217
# #13: what are the fares from dallas to san francisco on flight decilitre 217
# #14: what are the fares from dallas to san francisco on flight deciliter 217
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=177, intent:atis_airfare
# original sentence: what are the fares from dallas to san francisco on flight dl 217
#
#
# #0: what are the fares from dallas to san charles on medium dl about
# #1: what are the fares from osaka to san francisco on 3 dl unknown
# #2: what are the characters from ottawa to san francisco on flight dl /
# #3: what are the fares from charleston to san francisco on each dl ।
# #4: what are the fares from dallas to all monica on flight dl about
#
# #5: what are the fares from dallas to santa sanchez on training dl 217
# #6: what are the fees from chicago to san francisco on jetblue dl 217
# #7: what are the fares from toronto to pittsburgh francisco on flight sprain 217
# #8: what are the fares from dallas to san mesa on airliner pfg 217
# #9: what are the fares from dallas to san d.c. on aviation cvo 217
#
# #10: what are the fare from dallas to san francisco on flight decilitre 217
# #11: what are the fares from dallas to san francisco on escape dl 217
# #12: what are the fares from dallas to san francisco on flight of stairs dl 217
# #13: what are the fares from dallas to san francisco on flight of steps dl 217
# #14: what are the transportation from dallas to san francisco on flight decilitre 217
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# ...
# #4: id like to find the real by way hotel from baltimore to denver
#
# #5: phony like to find the costlier one way breakfasts from baltimore to denver
# #6: id like to find the cheapest well i entrees from baltimore to denver
# #7: wallet like to find the cheapest one thought costs from baltimore to denver
# #8: proof go to find the cheapest one way roundtrip from baltimore to denver
# #9: bogus like to find the cheapest one clear thanksgiving from baltimore to denver
#
# #10: id alike to find the cheapest unmatched way fare from baltimore to denver
# #11: i.d. like to obtain the punk one way fare from baltimore to denver
# #12: i.d. similar to find the cheapest one way transportation from baltimore to denver
# #13: id like to discover the cheapest one fashion menu from baltimore to denver
# #14: id like to find the cheapest one means fare from baltimore to denver
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=253, intent:atis_airfare
# original sentence: id like to find the cheapest one way fare from baltimore to denver
#
#
# #0: id start to become the cheapest one way back from baltimore to denver
# #1: id like to find the cheapest one haul airline from baltimore to,
# #2: id look to find the cheapest one, fare from baltimore to,
# #3: id like to find the cheapest white way route from baltimore to a
# #4: couples like to find the cheapest one way tube from oakland to denver
#
# #5: id like to nothing the cheapest one say fare from towson to denver
# #6: id thing to identify the cheapest one way fare from d.c. to denver
# #7: id like to identify the cheapest one? hikes from baltimore to denver
# #8: id like to find the accommodations one way dishes from baltimore to sonics
# #9: id like to find the feasible one way roundtrip from carolina to denver
#
# #10: idaho like to find the cheapest unrivalled style fare from baltimore to denver
# #11: id like to find the garish one way transportation from baltimore to denver
# #12: i.d. like to get hold the cheapest matchless way fare from baltimore to denver
# #13: i.d. like to encounter the cheapest one way fare from baltimore to denver
# #14: id like to find the tinny one way fare from baltimore to denver
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=253, intent:atis_airfare
# original sentence: id like to find the cheapest one way fare from baltimore to denver
#
#
# #0: id like to share the cheapest one door fare from florida to denver
# #1: id like to find the office post way job from baltimore to denver
# #2: would like to find the cheapest back way fare from baltimore to florida
# #3: wouldn like to discuss the cheapest one stage fare from baltimore to denver
# #4: id like to handle the cheapest one coach fare from nashville to denver
#
# #5: visas like to find the cheapest one rather passengers from baltimore to denver
# #6: id like to find the cheapest there through fare from anaheim to denver
# #7: id like to find the freshest one not fare from baltimore to steelers
# #8: verification come to find the cheapest eight way fare from baltimore to denver
# #9: id all to find the cheapest than way fare from baltimore to washington
#
# #10: id like to find the cheapest unitary way fare from baltimore to denver
# #11: id like to rule the loud one way fare from baltimore to denver
# #12: gem state like to find the cheapest one way fare from baltimore to denver
# #13: id like to find the sleazy unmatchable way fare from baltimore to denver
# #14: id like to find the cheapest unmatched mode fare from baltimore to denver
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=253, intent:atis_airfare
# original sentence: id like to find the cheapest one way fare from baltimore to denver
#
#
# #0: id like to find the cheapest fixed way bus from baltimore to $
# #1: also like to find the cheapest one for place from baltimore to denver
# #2: id like to find the cheapest half way... from baltimore to :
# #3: still desperate to find the cheapest one way fare from texas to denver
# #4: id like to guide the rare one way ship from baltimore to denver
#
# #5: id why to find the cheapest one out fare from baltimore to tampa
# #6: licence `` to find the cheapest one way fare from baltimore to spurs
# #7: id like to find the frills one way fare from toronto to utah
# #8: id like to get the soundest one way fare from cubs to denver
# #9: bogus others to find the cheapest they way fare from baltimore to denver
#
# #10: idaho like to find the cheapest one mode fare from baltimore to denver
# #11: id comparable to find the loud one mode fare from baltimore to denver
# #12: idaho like to determine the cheapest i way fare from baltimore to denver
# #13: id like to find the loud one elbow room fare from baltimore to denver
# #14: i.d. alike to find the cheapest one way fare from baltimore to denver
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : s
# ________________________________________________________________________________
#
# index = 255, intent: atis_airfare
# original sentence: how much does the american airlines flight 71 from dallas to san francisco cost
#
#
# #0: how much does the american continental flight schedule from dallas to brad francisco cost
# #1: how much does the hawaiian airlines trade comprise from dallas to san francisco cost
# #2: how much does the american airlines flight carry from calgary to san francisco over
# #3: how much does the american congress flight bring from rome to san francisco cost
# #4: how much does the first race pass 71 from dallas to san francisco cost
#
# #5: how well does the american airlines flight 71 from dallas to del jacinto cost
# #6: how like does the american airlines flight 71 from dallas to la moreno cost
# #7: how which does the american airlines travel 144 from dallas to san francisco cost
# #8: how but does the american airlines flight 49 from dallas to san francisco us$
# #9: how much does the american discount aboard 71 from dallas to san francisco premiums
#
# #10: how much does the american airway flight 71 from dallas to san francisco cost
# #11: how much does the american airlines flight seventy one from dallas to san francisco cost
# #12: how much does the american airlines flight 71 from dallas to san francisco cost
# #13: how much does the american airlines escape 71 from dallas to san francisco cost
# #14: how much does the american airlines flight 71 from dallas to san francisco price
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=255, intent:atis_airfare
# original sentence: how much does the american airlines flight 71 from dallas to san francisco cost
#
#
# #0: how much does the american airlines code 71 from tampa to san francisco he
# #1: how much does the american airlines flight 71 from milwaukee to san jorge?
# #2: how much does the western airlines flight 71 from dallas to san pablo ॥
# #3: how exactly does the american airlines strike 71 from dallas to san luis cost
# #4: how much does the spirit airlines flight 71 from dallas to san salvador oh
#
# #5: how but does the american airport flight 71 from dallas to siro francisco cost
# #6: how n't does the american airlines flight 71 from dallas to suu francisco pay
# #7: how need does the american airlines travel 90 from dallas to san francisco cost
# #8: how much does the american airlines flight 134 from arizona to san francisco worth
# #9: how much does the american frills shortly 71 from dallas to san francisco 10
#
# #10: how much does the american airlines flight seventy one from dallas to san francisco cost
# #11: how much does the american airlines flight of steps 71 from dallas to san francisco cost
# #12: how much does the american airline flight seventy one from dallas to san francisco cost
# #13: how much does the american airlines flight 71 from dallas to san francisco price
# #14: how much does the american airline business flight of stairs seventy one from dallas to san francisco cost
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : n
# enter new sentence: how much is the american airlines flight 71 from dallas to san francisco price
#
# original sentence: how much does the american airlines flight 71 from dallas to san francisco cost
# new sentence: how much is the american airlines flight 71 from dallas to san francisco price
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 258, intent: atis_airfare
# original sentence: first class round trip airfare from indianapolis to memphis
#
#
# #0: first class non trip airfare from indianapolis to brazil
# #1: eight class round trip coach from indianapolis to memphis
# #2: first class e 3 airfare from indianapolis to memphis
# #3: almost weekly round trip airfare from indianapolis to memphis
# #4: first class round 6 airfare from indianapolis to memphis
#
# #5: first these round trip round-trip from indianapolis to memphis
# #6: first class last travel airfare from indianapolis to memphis
# #7: first class round trip sightseeing from columbus to memphis
# #8: first class sunday ride airfare from indianapolis to memphis
# #9: best class weekend trip airfare from indianapolis to memphis
#
# #10: foremost class round trip airfare from capital of indiana to memphis
# #11: for the first time class round slip airfare from indianapolis to memphis
# #12: first class round trip airfare from capital of indiana to memphis
# #13: first class round trip airfare from capital of indiana to memphis
# #14: first of all class round trip airfare from indianapolis to memphis
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : n
# enter new sentence: first class round trip coach from indiana to memphis
#
# original sentence: first class round trip airfare from indianapolis to memphis
# new sentence: first class round trip coach from indiana to memphis
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 259, intent: atis_ground_service
# original sentence: tell me about ground transportation at san francisco
#
#
# #0: tell me about ground damage at that francisco
# #1: email me about ground clearance at san francisco
# #2: learn me about ground transportation at walt francisco
# #3: tell me about ground work at san and
# #4: tell me about ground crews at san quentin
#
# #5: give me about flying transportation at san francisco
# #6: tell me about ground commuter at san louis
# #7: tell me about ground airports at riverside francisco
# #8: remember me about ground transportation at san los
# #9: listen me about ground transportation at san solano
#
# #10: tell me about ground expatriation at san francisco
# #11: assure me about ground transit at san francisco
# #12: tell me about ground transportation at san francisco
# #13: tell me about ground transit at san francisco
# #14: tell me about terra firma transportation at san francisco
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : 13
#
# original sentence: tell me about ground transportation at san francisco
# new sentence: tell me about ground transit at san francisco
# is it ok? (y or n) y
# ________________________________________________________________________________
#
# index = 263, intent: atis_quantity
# original sentence: how many nonstop flights going from dallas to oakland july twenty seventh
#
#
# #0: how six nonstop flights going from louisville to albany july twenty seventh
# #1: how many nonstop trains going from cincinnati to there july twenty seventh
# #2: how many nonstop flight north from dallas to oakland morning twenty seventh
# #3: how many nonstop flights going from anchorage to oakland july - ॥
# #4: how many nonstop vehicles sailed from dallas to oakland july twenty months
#
# #5: how many nonstop flying going from nba to pitcher july twenty seventh
# #6: how many nonstops flights going from dallas to oakland 25 twenty 8th
# #7: how many nonstop flights going from dallas to diamondbacks week 30 seventh
# #8: how many 30-minute flights you from dallas to oakland july thirty-three seventh
# #9: how including nonstop flights back from dallas to oakland 1981 twenty seventh
#
# #10: how many day and night flights go from dallas to oakland july twenty one seventh
# #11: how many around the clock flying going from dallas to oakland july xx seventh
# #12: how many nonstop flights break down from dallas to oakland july twenty seventh
# #13: how many nonstop flights going from dallas to oakland july xx seventh
# #14: how many day and night trajectory live from dallas to oakland july twenty seventh
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=263, intent:atis_quantity
# original sentence: how many nonstop flights going from dallas to oakland july twenty seventh
#
#
# #0: how many nonstop flights going from guam to oakland july 2008 missing
# #1: how many nonstop flights are from dallas to la if twenty seventh
# #2: how many business emails going from dallas to oakland [UNK] twenty seventh
# #3: how many nonstop birds going from dallas to oakland | its seventh
# #4: how many vip flights going from dallas to richmond july our seventh
#
# #5: how many nonstop transport going from dallas to philadelphia 9 twenty seventh
# #6: how many nonstop shuttle going from dallas to usc july twenty 16th
# #7: how many nonstop flights should from dallas to oakland 11 twenty 2nd
# #8: how other nonstop flights so from dallas to oakland july twenty 58th
# #9: how sometimes nonstop flights? from dallas to nl july twenty seventh
#
# #10: how many nonstop flights go from dallas to oakland july 20 one seventh
# #11: how many nonstop flights pop off from dallas to oakland july twenty seventh
# #12: how many nonstop flights give out from dallas to oakland july twenty one seventh
# #13: how many around the clock flight give way from dallas to oakland july twenty seventh
# #14: how many nonstop flight going from dallas to oakland july twenty seventh
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : r
#
# index=263, intent:atis_quantity
# original sentence: how many nonstop flights going from dallas to oakland july twenty seventh
#
#
# #0: how with nonstop blocks going from memphis to oakland july twenty seventh
# #1: how many nonstop today was from dallas to oakland july twenty versus
# #2: how many nonstop flights going from dallas to oakland with i seventh
# #3: how nearly nonstop cases going from dallas to oakland as twenty seventh
# #4: how many nonstop flight going from dallas to rome july twenty what
#
# #5: how many nonstop flights going from dallas to michigan 1986 than seventh
# #6: how many nonstop flights even from dallas to dallas 2009 twenty seventh
# #7: how many nonstop flights going from dallas to peoria ended twenty 10th
# #8: how unlike nonstop flights going from dallas to browns 2004 twenty seventh
# #9: how however nonstop flights could from dallas to dallas july twenty seventh
#
# #10: how many nonstop flights go from dallas to oakland july twenty seventh
# #11: how many nonstop flights pass away from dallas to oakland july xx seventh
# #12: how many nonstop flights going from dallas to oakland july 20 seventh
# #13: how many nonstop flight going from dallas to oakland july twenty seventh
# #14: how many nonstop flying go from dallas to oakland july twenty seventh
#
# enter value between 0-14 or n to enter new sentence manually, r to regenerate sentences, s to skip sentence or b to break : b
# ________________________________________________________________________________
#
# last index = 263
# breaking...
# ________________________________________________________________________________

# %%
# import pickle

# f = open('train_data_generatedtrain_data_generated.pkl','wb')
# pickle.dump(train_data_generated, f)
# f.close()

# %%
len(train_data_generated)
# Out:
# 11

# %%
f = open('train_data_generated.pkl','rb')
new_dict = pickle.load(f)
f.close()
len(new_dict)
# Out:
# 11

# %%
create_iob_file('atis-generated-w-intent.iob',train_data_generated)

# %%
# %%capture
# !pip install textaugment

# %%
# import gensim.downloader as api

# # Download the models
# # fasttext_model300 = api.load('fasttext-wiki-news-subwords-300')
# conceptnet =  api.load('conceptnet-numberbatch-17-06-300')
# # word2vec_model300 = api.load('word2vec-google-news-300') # crash!
# # glove_model300 = api.load('glove-wiki-gigaword-300')

# # Get word embeddings
# # word2vec_model300.most_similar('support')
# Out:
# [==================================================] 100.0% 1168.7/1168.7MB downloaded

# %%
# from textaugment import Word2vec
# t = Word2vec(model=conceptnet)
# t.augment('i want to fly from baltimore to dallas round trip')

# %% [markdown]
# #Similar sentences

# %%
train_sentences_dup_free = list()
for i in range(len(train_intents_dup_free)):
  if (train_intents_dup_free[i] == 'atis_flight'): 
    item = " ".join(train_words_dup_free[i]) #stop words?
    train_sentences_dup_free.append(item)

len(train_sentences_dup_free)
# Out:
# 3443

# %%
# %%capture
# !pip install -U sentence-transformers

# %%
# %%capture
from sentence_transformers import SentenceTransformer, util
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
import numpy as np
import time  

corpus_sentences = train_sentences_dup_free
embedder = SentenceTransformer('paraphrase-mpnet-base-v2')

# %%
# finding similar pairs

#Compute embeddings
corpus_embeddings = embedder.encode(corpus_sentences,show_progress_bar=True, convert_to_tensor=True)

#Compute cosine-similarities for each sentence with each other sentence
cosine_scores = util.pytorch_cos_sim(corpus_embeddings, corpus_embeddings)

#Find the pairs with the highest cosine similarity scores
pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

#Sort scores in decreasing order
pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)

for pair in pairs[0:10]:
    i, j = pair['index']
    print("{} \t\t {} \t\t Score: {:.4f}".format(corpus_sentences[i], corpus_sentences[j], pair['score']))
# Out:
# Batches:   0%|          | 0/108 [00:00<?, ?it/s]

# %%
f = open('similar-pairs.txt', 'w')
for pair in pairs:
  i, j = pair['index']
  f.write("{} \t\t {} \t\t Score: {:.4f}\n".format(corpus_sentences[i], corpus_sentences[j], pair['score']))
  #print("{} \t\t {} \t\t Score: {:.4f}".format(sentences[i], sentences[j], pair['score']))
  if (pair['score'] < 0.8): break
f.close()

# %%
# Corpus with example sentences
corpus_sentences = train_sentences_dup_free
corpus_embeddings = embedder.encode(corpus_sentences, show_progress_bar=True)

# Normalize the embeddings to unit length
corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)
# Out:
# Batches:   0%|          | 0/108 [00:00<?, ?it/s]

# %%
# # K-means

# num_clusters = 2000
# clustering_model = KMeans(n_clusters=num_clusters)
# clustering_model.fit(corpus_embeddings)
# cluster_assignment = clustering_model.labels_

# clustered_sentences = [[] for i in range(num_clusters)]
# for sentence_id, cluster_id in enumerate(cluster_assignment):
#     clustered_sentences[cluster_id].append(corpus_sentences[sentence_id])

# %%
# reduced_data = PCA(n_components=2).fit_transform(corpus_embeddings)
# kmeans = KMeans(n_clusters=num_clusters)
# kmeans.fit(reduced_data)

# # Step size of the mesh. Decrease to increase the quality of the VQ.
# h = .01     # point in the mesh [x_min, x_max]x[y_min, y_max].

# # Plot the decision boundary. For that, we will assign a color to each
# x_min, x_max = reduced_data[:, 0].min() - 1, reduced_data[:, 0].max() + 1
# y_min, y_max = reduced_data[:, 1].min() - 1, reduced_data[:, 1].max() + 1
# xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# # Obtain labels for each point in mesh. Use last trained model.
# Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

# # Put the result into a color plot
# Z = Z.reshape(xx.shape)
# plt.figure(figsize=(24, 12))
# plt.clf()
# plt.imshow(Z, interpolation="nearest",
#            extent=(xx.min(), xx.max(), yy.min(), yy.max()),
#            cmap=plt.cm.Paired, aspect="auto", origin="lower")

# plt.plot(reduced_data[:, 0], reduced_data[:, 1], 'k.', markersize=5)
# # Plot the centroids as a white X
# # centroids = kmeans.cluster_centers_
# # plt.scatter(centroids[:, 0], centroids[:, 1], marker="x", s=169, linewidths=3,
# #             color="w", zorder=10)
# plt.title("K-means clustering (PCA-reduced data)")
#           # "Centroids are marked with white cross")
# plt.xlim(x_min, x_max)
# plt.ylim(y_min, y_max)
# plt.xticks(())
# plt.yticks(())
# plt.show()

# %%
# # To getter a better understanding of interaction of the dimensions
# # plot the first three PCA dimensions

# fig = plt.figure(1, figsize=(16, 12))
# ax = Axes3D(fig, elev=-150, azim=110)
# X_reduced = PCA(n_components=3).fit_transform(corpus_embeddings)
# ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2],c=kmeans.labels_,
#            cmap=plt.cm.Set1, edgecolor='k', s=40)
# ax.set_title("First three PCA directions - Kmeans")
# ax.set_xlabel("1st eigenvector")
# ax.w_xaxis.set_ticklabels([])
# ax.set_ylabel("2nd eigenvector")
# ax.w_yaxis.set_ticklabels([])
# ax.set_zlabel("3rd eigenvector")
# ax.w_zaxis.set_ticklabels([])

# plt.show()

# %%
# pca = PCA(n_components=2)
# X_r = pca.fit(corpus_embeddings).transform(corpus_embeddings)


# # Percentage of variance explained for each components
# # print('explained variance ratio (first two components): %s'
# #       % str(pca.explained_variance_ratio_))

# plt.figure(1, figsize=(16, 12))

# for i, target_name in zip([x for x in range(len(kmeans.labels_))], set(kmeans.labels_)):
#     plt.scatter(X_r[kmeans.labels_ == i, 0], X_r[ kmeans.labels_ == i, 1], alpha=.8, label=target_name)
# # plt.legend(loc='best', shadow=False, scatterpoints=1)
# plt.title('PCA K-means')

# plt.show()

# %%
# f = open('Clusters-k-means.txt', 'w')
# for i, cluster in enumerate(clustered_sentences):
#     f.write("Cluster %d, #%d Elements :\n" % (i+1, len(cluster)) + str(cluster) + "\n\n\n")
#     # print("Cluster ", i+1)
#     # print(cluster)
#     # print("")
# f.close()

# %%
# Agglomerative Clustering

# clustering_model = AgglomerativeClustering(n_clusters=None, distance_threshold=1) 
clustering_model = AgglomerativeClustering(n_clusters=None, affinity='cosine', linkage='average', distance_threshold=0.1)
model = clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences: clustered_sentences[cluster_id] = list()
    clustered_sentences[cluster_id].append(corpus_sentences[sentence_id])

len(clustered_sentences)
# Out:
# 1739

# %%
pca = PCA(n_components=2)
X_r = pca.fit(corpus_embeddings).transform(corpus_embeddings)


# Percentage of variance explained for each components
# print('explained variance ratio (first two components): %s'
#       % str(pca.explained_variance_ratio_))

plt.figure(1, figsize=(16, 12))

for i, target_name in zip([x for x in range(len(clustering_model.labels_))], set(clustering_model.labels_)):
    plt.scatter(X_r[clustering_model.labels_ == i, 0], X_r[ clustering_model.labels_ == i, 1], alpha=.8, label=target_name)
# plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA Agglomerative Clustering')

plt.show()

# %%
# To getter a better understanding of interaction of the dimensions
# plot the first three PCA dimensions

fig = plt.figure(1, figsize=(16, 12))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(corpus_embeddings)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2],c=clustering_model.labels_,
           cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.set_title("First three PCA directions - Agglomerative Clustering")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])

plt.show()

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)
  
plt.figure(figsize=(24, 10))
plt.title('Hierarchical Clustering Dendrogram')
plot_dendrogram(model)#, truncate_mode='level', p=7)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %%
f = open('Clusters-Agglomerative.txt', 'w')
for i, cluster in clustered_sentences.items():
    if (len(cluster) > 1): f.write("Cluster %d, #%d Elements :\n" % (i+1, len(cluster)) + str(cluster) + "\n\n\n")
    # print("Cluster ", i+1)
    # print(cluster)
    # print("")
f.close()

# %%
import math
percentage = 0.5
train_data_undersampled = list()
for i, cluster in clustered_sentences.items():
  sorted_cluster = sorted(cluster, key=len,  reverse=True)
  # print('original count = %d, downsampled count = %d' %(len(sorted_cluster), math.ceil(percentage * len(sorted_cluster))))
  for j in range(math.ceil(percentage * len(sorted_cluster))):
     item = next(item for item in train_data_dup_free if item["words"] == sorted_cluster[j].strip().split())
     train_data_undersampled.append(item)     

f = open('train_data_undersampled.pkl','wb')
pickle.dump(train_data_undersampled, f)
f.close()

len(train_data_undersampled)
# Out:
# 2344

# %%
f = open('train_data_undersampled.pkl','rb')
new_dict = pickle.load(f)
f.close()
len(new_dict)
# Out:
# 2344

# %%
create_iob_file('atis-undersampled-w-intent.iob',train_data_undersampled)

# %%
# import sys
# sys.setrecursionlimit(15000)

# %%
Z = hierarchy.linkage(corpus_embeddings, 'ward')
plt.figure(figsize=(24, 8))
plt.title('Dendrogram')
dn = hierarchy.dendrogram(Z)
plt.show()

# %%
# # Faster Clustering

# corpus_sentences = train_sentences_dup_free
# print("Encode the corpus. This might take a while")
# corpus_embeddings = embedder.encode(corpus_sentences, batch_size=64, show_progress_bar=True, convert_to_tensor=True)

# %%
# #Two parameters to tune:
# #min_cluster_size: Only consider cluster that have at least 1 elements
# #threshold: Consider sentence pairs with a cosine-similarity larger than threshold as similar
# clusters = util.community_detection(corpus_embeddings, min_community_size=1, threshold=0.95)

# %%
# f = open('Clusters.txt', 'w')
# #Print for all clusters the top 3 and bottom 3 elements
# for i, cluster in enumerate(clusters):
#     #print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
#     data = [corpus_sentences[sentence_id] for sentence_id in cluster]
#     f.write("Cluster {}, #{} Elements \n".format(i+1, len(cluster)) + str(data) + "\n\n\n")

#     # for sentence_id in cluster[0:3]:
#     #     #print("\t", corpus_sentences[sentence_id])
#     #     f.write("\t" + corpus_sentences[sentence_id])
#     # #print("\t", "...")
#     # f.write("\t ...")
#     # for sentence_id in cluster[-3:]:
#     #     #print("\t", corpus_sentences[sentence_id])
#     #     f.write("\t" + corpus_sentences[sentence_id])
    
# f.close()
